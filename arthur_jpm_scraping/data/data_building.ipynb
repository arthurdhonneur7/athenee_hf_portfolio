# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# data_dict
res = []

for keys, values in data_dict.items():
    res += values['results']

df = pd.DataFrame(res)

df.head()

# %%
df.to_csv('./data_jpm.csv',index=False)

# %%
import seaborn as sns

sns.set_theme()

sns.ecdfplot(df['track_record_months']/12)
